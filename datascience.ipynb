# %%
import pandas as pd                        #import pandas pakage
import numpy as np                          #import numpy pakage
import matplotlib.pyplot as plt             #import matplotlib.pyplot pakage  
import seas

# %%
import re

# %%
#Read the csv file
data=pd.read_csv(r"C:\Users\Bhaskar\Data Sciece files - Copy0\datascienceproject.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                              Brand    Price  \
# 0           0  Lenovo Ideapad Slim 3 Celeron Dual Core - (4 G...  ₹23,990
# 1           1  HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...  ₹49,990
# 2           2  acer Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/...  ₹55,990
# 3           3  Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 4600...  ₹59,990
# 4           4  Lenovo Ideapad Slim 3i Core i3 10th Gen - (8 G...  ₹35,990
#
#        MRP                                          Processor  Rating  \
# 0  ₹30,690  Intel Celeron Dual Core Processor4 GB DDR4 RAM...     4.2
# 1  ₹56,144  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64...     4.2
# 2  ₹89,990  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...     4.5
# 3  ₹82,490  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...     4.5
# 4  ₹52,490  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...     4.3
#
#                          Reviews                       Reviews1  \
# ...

# %% [markdown]
# # .drop() examples for  dropping a column/columns

# %%
data.drop(['Unnamed: 0'], axis=1,inplace=True)
data.drop(['Ram'], axis=1,inplace=True)

# %% [markdown]
# # cleaning the data

# %%
data['Price'] = data['Price'].str.replace('₹', '')
data['Price'] = data['Price'].str.replace(',','')

# %%
data['MRP'] = data['MRP'].str.replace('₹', '')
data['MRP'] = data['MRP'].str.replace(',','')

# %%
data['Ava_offer'] = data['Ava_offer'].str.replace('% off', '')

# %% [markdown]
# # above 4.5 means=star
#
# below 4.5 means= below

# %%
data['top_rating']=data.Rating.apply(lambda x:"star" if x>=4 else "below ")

# %% [markdown]
# # Rename the columns

# %%
data.rename(columns={'Reviews': 'Rating1'},inplace = True)

# %%
data.rename(columns={'Rating': 'Reviews'},inplace = True)

# %%
data
# Out:
#                                                  Brand   Price    MRP  \
# 0    Lenovo Ideapad Slim 3 Celeron Dual Core - (4 G...   23990  30690
# 1    HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...   49990  56144
# 2    acer Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/...   55990  89990
# 3    Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 4600...   59990  82490
# 4    Lenovo Ideapad Slim 3i Core i3 10th Gen - (8 G...   35990  52490
# ..                                                 ...     ...    ...
# 446  acer Aspire 5 Core i5 10th Gen - (8 GB/512 GB ...   57949  44990
# 447  Lenovo Ideapad Gaming 3 Core i5 - (8 GB/1 TB H...   78938  78990
# 448  ASUS ExpertBook B9 Core i5 10th Gen - (8 GB/51...  132790  55900
# 449  ASUS ZenBook 13 Core i5 10th Gen - (8 GB/512 G...   77990  49729
# 450  Lenovo Ideapad 3 Core i3 10th Gen - (4 GB/1 TB...   32990  44990
#
#                                              Processor  Reviews  \
# ...

# %% [markdown]
# # Rating1

# %%
data['Rating1'] = data['Rating1'].str[:10]

# %%
data['Rating1'] = data['Rating1'].str.replace('Ratings', '')

# %%
data['Rating1'] = data['Rating1'].str.replace('Rati', '')

# %%
data['Rating1'] = data['Rating1'].str.replace('ng', '')

# %%
data['Rating1'] = data['Rating1'].str.replace('Rat', '')

# %%
data['Rating1'] = data['Rating1'].str.replace(',', '')

# %%
for i in data['Rating1']:

    print(i)
# Out:
# 495
# 8757
# 527
# 974
# 178
# 3436
# 245
# 3311
# 141
# 100
# 398
# 960
# 5927
# 300
# 1595
# 1026
# 50
# 8408
# 12
# 631
# 75
# 643
# 30205
# 495
# 8757
# 527
# 974
# 178
# 3436
# 245
# 3311
# 141
# 100
# 398
# 960
# 5927
# 300
# 1595
# 1026
# 50
# 8408
# 12
# 631
# 75
# 643
# 30205
# 293
# 27
# 335
# 1429
# 65
# 311
# 413
# 35
# 26
# 2475
# 512
# 1041
# 32
# 415
# 320
# 543
# 15
# 2475
# 1161
# 433
# 4063
# 287
# 1294
# 542
# 329
# 266
# 67
# 1157
# 132
# 362
# 149
# 16
# 868
# 297
# 8
# 908
# 770
# 434
# 721
# 2466
# 19
# 71
# 110
# 955
# 6
# 77
# 718
# 955
# 110
# 899
# 113
# 66
# 642
# 45
# 289
# 170
# 2097
# 341
# 31
# 72
# 81
# 23
# 51
# 13
# 349
# 770
# 3
# 88
# 68
# 711
# 713
# 15
# 689
# 231
# 287
# 90
# 971
# 54
# 904
# 666
# 667
# 10
# 3
# 40
# 29
# 1842
# 510
# 71
# 6
# 6
# 154
# 154
# 203
# 153
# 87
# 6
# 115
# 36
# 90
# 42
# 690
# 17
# 78
# 500
# 22
# 22
# 874
# 117
# 20
# 1852
# 716
# 971
# 7
# 21
# 19
# 532
# 6198
# 9
# 44
# 1130
# 191
# 374
# 287
# 63
# 35
# 6
# ...

# %% [markdown]
# # Reviews1

# %%
data['Reviews1'] = data['Reviews1'].str[:30]

# %%
data['Reviews1'] = data['Reviews1'].str.replace('Ratings', '')

# %%
data['Reviews1'] = data['Reviews1'].str.replace('Reviews', '')

# %%
data['Reviews1'] = data['Reviews1'].str.replace('&', '')

# %%
data['Reviews1'] = data['Reviews1'].str[3:]

# %%
data['Reviews1'] = data['Reviews1'].str.replace('', '')

# %%
data['Reviews1'] = data['Reviews1'].str[-7:]

# %%
data['Reviews1'] = data['Reviews1'].str.replace(',', '')

# %%
for i in data['Reviews1']:

    print(i)
# Out:
#    74
#  1224
#    98
#    146
#    15
#    375
#    27
#    462
#    14
#    14
#    55
#    143
#    774
#    38
#    162
#    154
#   7
#    998
#   3
#    132
#   17
#    88
#  3269
#    74
#  1224
#    98
#    146
#    15
#    375
#    27
#    462
#    14
#    14
#    55
#    143
#    774
#    38
#    162
#    154
#   7
#    998
#   3
#    132
#   17
#    88
#  3269
#    35
#   6
#    48
#    211
#   12
#    53
#    65
#   3
#   10
#    289
#    74
#    141
#   8
#    54
#    33
#    73
#   3
#    289
#    132
#    65
#    603
#    34
#    174
#    58
#    68
#    32
#   13
#    197
#    23
#    42
#    20
#   3
#    141
#    27
#  3
#    168
#    125
#    78
#    96
#    286
#   0
#   3
#    9
#    181
#  1
#   18
#    103
#    181
#    9
#    160
#    12
#   13
#    70
#   6
#    48
#    30
#    238
#    27
#   9
#   9
#   7
#   5
#   3
#   1
#    35
#    111
#  1
#   9
#   10
#    116
#    116
#   3
#    86
#    38
#    34
#   13
#    186
#   16
#    160
#    88
#    82
# ...

# %% [markdown]
# here I'm separate the Brand name and model name

# %%
data.dropna(inplace = True)
  

new = data["Brand"].str.split(" ", n = 1, expand = True)
  
#
data["First Name"]= new[0]
  
# making separate last name column from new data frame
data["Last Name"]= new[1]
  
# Dropping old Name columns
data.drop(columns =["Brand"], inplace = True)

# %% [markdown]
# ReIndex for dataframe

# %%
data=data.reindex(columns= ['First Name', 'Last Name', 'Price','MRP','Processor','Reviews','Rating1','Reviews1','Ram','Ava_offer','top_rating'])

print(data)
# Out:
#     First Name                                          Last Name   Price  \
# 0       Lenovo  Ideapad Slim 3 Celeron Dual Core - (4 GB/256 G...   23990
# 1           HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...   49990
# 2         acer  Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/512 G...   55990
# 3       Lenovo  Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H - (8 ...   59990
# 4       Lenovo  Ideapad Slim 3i Core i3 10th Gen - (8 GB/256 G...   35990
# ..         ...                                                ...     ...
# 446       acer  Aspire 5 Core i5 10th Gen - (8 GB/512 GB SSD/W...   57949
# 447     Lenovo  Ideapad Gaming 3 Core i5 - (8 GB/1 TB HDD/256 ...   78938
# 448       ASUS  ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB ...  132790
# 449       ASUS  ZenBook 13 Core i5 10th Gen - (8 GB/512 GB SSD...   77990
# 450     Lenovo  Ideapad 3 Core i3 10th Gen - (4 GB/1 TB HDD/Wi...   32990
#
#        MRP                                          Processor  Reviews  \
# ...

# %% [markdown]
# Rename firstname into Brand_Name and last Name into Model_Name

# %%
data.rename(columns={'First Name': 'Brand_Name'},inplace = True)

# %%
data.rename(columns={'Last Name': 'Model_Name'},inplace = True)

# %%
data
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 0       Lenovo  Ideapad Slim 3 Celeron Dual Core - (4 GB/256 G...   23990
# 1           HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...   49990
# 2         acer  Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/512 G...   55990
# 3       Lenovo  Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H - (8 ...   59990
# 4       Lenovo  Ideapad Slim 3i Core i3 10th Gen - (8 GB/256 G...   35990
# ..         ...                                                ...     ...
# 446       acer  Aspire 5 Core i5 10th Gen - (8 GB/512 GB SSD/W...   57949
# 447     Lenovo  Ideapad Gaming 3 Core i5 - (8 GB/1 TB HDD/256 ...   78938
# 448       ASUS  ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB ...  132790
# 449       ASUS  ZenBook 13 Core i5 10th Gen - (8 GB/512 GB SSD...   77990
# 450     Lenovo  Ideapad 3 Core i3 10th Gen - (4 GB/1 TB HDD/Wi...   32990
#
#        MRP                                          Processor  Reviews  \
# ...

# %% [markdown]
# In Model_Name column i want only in between  bracket data

# %%
Ram_data=data['Model_Name'].apply(lambda st: st[st.find("(")+1:st.find(")")])

# %%
for i in Ram_data:
    print(i)
# Out:
# 4 GB/256 GB SSD/Windows 10 Home
# 8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA GeFor..
# 8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce ..
# 8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graph..
# 8 GB/256 GB SSD/Windows 10 Home
# 8 GB/256 GB SSD/Windows 10 Home
# 4 GB/1 TB HDD/Windows 10 Home
# 8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650..
# 4 GB/1 TB HDD/Windows 10 Home
# 8 GB/256 GB SSD/Windows 10 Home
# 8 GB/256 GB SSD/Windows 10 Home
# 8 GB/512 GB SSD/Windows 10 Home
# 4 GB/1 TB HDD/Windows 10 Home
# 8 GB/1 TB HDD/Windows 10 Home
# 8 GB/1 TB HDD/Windows 10 Home
# 4 GB/1 TB HDD/Windows 10 Home
# 4 GB/1 TB HDD/Endless
# 4 GB/1 TB HDD/Windows 10 Home
# 8 GB/512 GB SSD/Windows 10 Home
# 8 GB/512 GB SSD/Windows 10 Home
# 8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForc..
# 16 GB/512 GB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce GTX 166..
# 4 GB/256 GB SSD/Windows 10 Home
# 8 GB/128 GB SSD/Mac OS Sierra
# ...

# %%
Ram_data = Ram_data.str[:1]

# %%
Ram_data
# Out:
# 0      4
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 446    8
# 447    8
# 448    8
# 449    8
# 450    4
# Name: Model_Name, Length: 451, dtype: object

# %% [markdown]
# Here I'm adding new column

# %%
data['Ram1']=[4,
8,
8,
8,
8,
8,
4,
8,
4,
8,
8,
8,
4,
8,
8,
4,
4,
4,
8,
8,
8,
1,
4,
8,
4,
8,
8,
8,
8,
8,
4,
8,
4,
8,
8,
8,
4,
8,
8,
4,
4,
4,
8,
8,
8,
1,
4,
8,
8,
8,
8,
8,
4,
8,
8,
8,
8,
8,
4,
8,
8,
8,
8,
8,
8,
8,
8,
8,
4,
8,
8,
8,
8,
8,
8,
1,
8,
4,
1,
8,
8,
8,
8,
8,
1,
4,
8,
2,
8,
4,
8,
8,
8,
4,
8,
8,
8,
8,
8,
8,
8,
4,
8,
8,
2,
8,
4,
8,
4,
8,
1,
8,
4,
4,
8,
1,
1,
8,
8,
1,
1,
8,
8,
8,
3,
3,
4,
8,
8,
8,
8,
8,
1,
8,
8,
1,
8,
8,
1,
8,
4,
8,
8,
4,
4,
8,
8,
1,
8,
8,
8,
8,
8,
4,
8,
8,
8,
8,
8,
8,
1,
8,
8,
8,
1,
4,
8,
4,
4,
4,
8,
4,
8,
8,
8,
4,
8,
4,
1,
8,
8,
3,
8,
8,
1,
1,
8,
1,
8,
4,
1,
8,
8,
1,
8,
8,
1,
1,
8,
3,
8,
8,
8,
4,
8,
4,
8,
8,
4,
8,
8,
1,
4,
8,
8,
1,
1,
4,
8,
8,
8,
8,
4,
8,
8,
8,
8,
8,
1,
8,
8,
8,
8,
8,
4,
8,
8,
8,
4,
4,
4,
8,
8,
1,
8,
8,
4,
1,
8,
8,
8,
8,
8,
8,
1,
8,
8,
8,
8,
8,
8,
1,
8,
8,
8,
8,
8,
8,
1,
8,
4,
4,
8,
8,
8,
8,
8,
8,
8,
8,
4,
8,
8,
8,
8,
1,
8,
1,
8,
3,
8,
4,
4,
8,
8,
4,
8,
4,
3,
4,
3,
3,
2,
8,
8,
1,
1,
1,
2,
8,
3,
8,
8,
3,
8,
1,
8,
8,
1,
8,
8,
8,
8,
1,
4,
1,
3,
1,
8,
8,
4,
1,
1,
4,
8,
8,
1,
1,
4,
8,
8,
1,
1,
8,
1,
8,
8,
8,
8,
8,
8,
8,
8,
1,
1,
1,
8,
8,
8,
8,
3,
2,
8,
1,
8,
8,
8,
8,
8,
8,
8,
8,
8,
8,
8,
8,
8,
4,
8,
8,
1,
1,
8,
8,
1,
1,
8,
8,
1,
1,
8,
8,
1,
8,
8,
1,
8,
8,
1,
4,
8,
8,
8,
8,
8,
8,
8,
8,
8,
8,
8,
8,
1,
8,
8,
8,
3,
8,
8,
4,
4,
8,
3,
4,
8,
8,
8,
8,
8,
8,
8,
1,
1,
8,
8,
8,
8,
1,
8,
8,
8,
8,
8,
4,
8,
8,
8,
8,
8,
8,
4]

# %%
Ram_data = Ram_data.str.replace(',', '')

# %%
Ram_data
# Out:
# 0      4
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 446    8
# 447    8
# 448    8
# 449    8
# 450    4
# Name: Model_Name, Length: 451, dtype: object

# %%
data
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 0       Lenovo  Ideapad Slim 3 Celeron Dual Core - (4 GB/256 G...   23990
# 1           HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...   49990
# 2         acer  Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/512 G...   55990
# 3       Lenovo  Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H - (8 ...   59990
# 4       Lenovo  Ideapad Slim 3i Core i3 10th Gen - (8 GB/256 G...   35990
# ..         ...                                                ...     ...
# 446       acer  Aspire 5 Core i5 10th Gen - (8 GB/512 GB SSD/W...   57949
# 447     Lenovo  Ideapad Gaming 3 Core i5 - (8 GB/1 TB HDD/256 ...   78938
# 448       ASUS  ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB ...  132790
# 449       ASUS  ZenBook 13 Core i5 10th Gen - (8 GB/512 GB SSD...   77990
# 450     Lenovo  Ideapad 3 Core i3 10th Gen - (4 GB/1 TB HDD/Wi...   32990
#
#        MRP                                          Processor  Reviews  \
# ...

# %% [markdown]
# Here I'm separate for ssd

# %%
Ram_data2=data['Model_Name'].apply(lambda st: st[st.find("(")+1:st.find(")")])

# %%
Ram_data2
# Out:
# 0                        4 GB/256 GB SSD/Windows 10 Home
# 1      8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NV...
# 2      8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/...
# 3      8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB ...
# 4                        8 GB/256 GB SSD/Windows 10 Home
#                              ...
# 446                      8 GB/512 GB SSD/Windows 10 Home
# 447    8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB ...
# 448                       8 GB/512 GB SSD/Windows 10 Pro
# 449                      8 GB/512 GB SSD/Windows 10 Home
# 450                        4 GB/1 TB HDD/Windows 10 Home
# Name: Model_Name, Length: 451, dtype: object

# %%
Ram_data2 = Ram_data2.str[5:7]

# %%
Ram_data2
# Out:
# 0      25
# 1      1
# 2      51
# 3      1
# 4      25
#        ..
# 446    51
# 447    1
# 448    51
# 449    51
# 450    1
# Name: Model_Name, Length: 451, dtype: object

# %%
for i in Ram_data2:
    print(i)
# Out:
# 25
# 1
# 51
# 1
# 25
# 25
# 1
# 51
# 1
# 25
# 25
# 51
# 1
# 1
# 1
# 1
# 1
# 1
# 51
# 51
# 51
# /5
# 25
# 12
# 25
# 1
# 51
# 1
# 25
# 25
# 1
# 51
# 1
# 25
# 25
# 51
# 1
# 1
# 1
# 1
# 1
# 1
# 51
# 51
# 51
# /5
# 25
# 12
# 1
# 51
# 51
# 1
# 1
# 51
# 1
# 1
# 1
# 51
# 25
# 51
# 1
# 1
# 51
# 1
# 51
# 25
# 51
# 51
# 1
# 51
# 51
# 1
# 51
# 25
# 51
# /1
# 1
# 1
# /5
# 1
# 51
# 1
# 1
# 51
# /5
# 1
# 25
#
# 51
# 1
# 25
# 25
# 51
# 1
# 51
# 1
# 51
# 25
# 51
# 1
# 51
# 1
# 51
# 25
#
# 1
# 25
# 25
# 25
# 51
# /1
# 12
# 1
# 1
# 25
# /1
# /5
# 1
# 1
#  +
#  +
# 51
# 51
# 1
# /1
# 51
# 1
# 51
# 51
# 51
# 1
# 51
# /1
# 1
# 51
# /5
# 25
# 51
# /1
# 1
# 1
# 1
# 1
# 51
# 51
# 51
# 1
# /5
# 1
# 1
# 51
# 12
# 51
# 64
# 25
# 51
# 51
# 1
# 51
# 51
# /1
# 51
# 1
# 51
# /5
# 1
# 51
# 1
# 1
# 1
# 51
# 25
# 51
# 1
# 1
# 1
# 1
# 64
# /5
# 51
# 51
# /1
# 51
# 51
# /5
# /5
# 51
#  +
# 51
# 51
# /5
# 1
# 1
# /1
# 1
# 1
# /5
# /5
# 1
# /2
# 51
# 51
# 25
# 1
# 1
# 1
# 51
# 51
# 1
# 25
# 51
# /1
# 25
# 51
# 1
# /1
# ...

# %%
Ram_data2 = Ram_data2.str.replace('/', '')
Ram_data2 = Ram_data2.str.replace('+', '')

# %% [markdown]
# # I.m adding SSD to DataFrame

# %%
data['SSD']=[256,
1 ,
512,
1 ,
256,
256,
1 ,
512,
1 ,
256,
256,
512,
1 ,
1 ,
1 ,
1 ,
1 ,
1 ,
512,
512,
512,
512,
256,
128,
256,
1 ,
512,
1 ,
256,
256,
1 ,
512,
1 ,
256,
256,
512,
1 ,
1 ,
1 ,
1 ,
1 ,
1 ,
512,
512,
512,
512,
256,
128,
1 ,
512,
512,
1 ,
1 ,
512,
1 ,
1 ,
1 ,
512,
256,
512,
1 ,
1 ,
512,
1 ,
512,
256,
512,
512,
1 ,
512,
512,
1 ,
512,
256,
512,
1,
1 ,
1 ,
512,
1 ,
512,
1 ,
1 ,
512,
512,
1 ,
256,
256,
512,
1 ,
256,
256,
512,
1 ,
512,
1 ,
512,
256,
512,
1 ,
512,
1 ,
512,
256,
256,
1 ,
256,
256,
256,
512,
1,
128,
1 ,
1 ,
256,
1,
512,
1 ,
1 ,
256,
256,
512,
512,
1 ,
1,
512,
1 ,
512,
512,
512,
1 ,
512,
1,
1 ,
512,
512,
256,
512,
1,
1 ,
1 ,
1 ,
1 ,
512,
512,
512,
1 ,
512,
1 ,
1 ,
512,
128,
512,
64,
256,
512,
512,
1 ,
512,
512,
1,
512,
1 ,
512,
512,
1,
512,
1 ,
1 ,
1 ,
512,
256,
512,
1 ,
1 ,
1 ,
1 ,
64,
512,
512,
512,
1,
512,
512,
512,
512,
512,
 256,
512,
512,
512,
1 ,
1 ,
1,
1 ,
1 ,
512,
512,
1 ,
256,
512,
512,
256,
1 ,
1 ,
1 ,
512,
512,
1 ,
256,
512,
1,
256,
512,
1 ,
1,
1,
256,
512,
512,
512,
512,
1 ,
512,
512,
512,
512,
512,
1,
512,
512,
512,
512,
512,
1 ,
512,
1 ,
1 ,
1 ,
256,
256,
512,
512,
1,
512,
256,
1 ,
256,
512,
1 ,
512,
512,
512,
1 ,
512,
256,
512,
256,
512,
512,
256,
512,
512,
512,
512,
512,
512,
256,
1,
512,
256,
1 ,
256,
512,
1 ,
256,
1 ,
512,
512,
256,
1 ,
512,
512,
512,
1 ,
1,
1 ,
1,
256,
1,
512,
1 ,
1 ,
512,
512,
1 ,
512,
1 ,
1,
256,
256,
1,
1,
512,
256,
1,
512,
1,
256,
256,
1,
1, 
256,
1,
 1,
512,
256,
256,
1,
512,
512,
256,
 1,
1,
256,
1,
1,
1,
256,
512,
256,
512,
1,
1 ,
256,
1 ,
512,
1,
1 ,
256,
1 ,
1,
512,
256,
512,
256,
1 ,
256,
512,
512,
512,
512,
1 ,
1,
1,
1,
128,
512,
512,
512,
1,
256,
256,
1,
256,
1 ,
1 ,
2 ,
1 ,
512,
512,
512,
512,
1 ,
512,
1 ,
512,
1 ,
1 ,
1 ,
1,
1,
512,
256,
1,
1,
512,
256,
512,
512,
512,
256,
512,
1 ,
1 ,
1,
1 ,
1 ,
1,
1 ,
512,
1 ,
1 ,
1 ,
512,
512,
1 ,
512,
512,
1 ,
256,
1 ,
1,
512,
256,
512,
1,
512,
512,
64,
1 ,
256,
1,
256,
1 ,
512,
512,
1 ,
1 ,
512,
512,
512,
1,
1 ,
1 ,
128,
512,
1,
512,
256,
1 ,
512,
1 ,
512,
1 ,
512,
512,
1 ,
512,
512,
1 ]

# %%
data['Ram_GB']
# Out:
# 0      4
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 446    8
# 447    8
# 448    8
# 449    8
# 450    4
# Name: Ram_GB, Length: 451, dtype: int64

# %% [markdown]
# # Finally I'm updating the all the colums

# %%
data.rename(columns={'Ram1': 'Ram_GB'},inplace = True)

# %%
data.rename(columns={'Reviews': 'Star'},inplace = True)

# %%
data.rename(columns={'Rating1': 'Rating'},inplace = True)

# %%
data.rename(columns={'Reviews1': 'Reviews'},inplace = True)

# %%
data
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 0       Lenovo  Ideapad Slim 3 Celeron Dual Core - (4 GB/256 G...   23990
# 1           HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...   49990
# 2         acer  Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/512 G...   55990
# 3       Lenovo  Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H - (8 ...   59990
# 4       Lenovo  Ideapad Slim 3i Core i3 10th Gen - (8 GB/256 G...   35990
# ..         ...                                                ...     ...
# 446       acer  Aspire 5 Core i5 10th Gen - (8 GB/512 GB SSD/W...   57949
# 447     Lenovo  Ideapad Gaming 3 Core i5 - (8 GB/1 TB HDD/256 ...   78938
# 448       ASUS  ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB ...  132790
# 449       ASUS  ZenBook 13 Core i5 10th Gen - (8 GB/512 GB SSD...   77990
# 450     Lenovo  Ideapad 3 Core i3 10th Gen - (4 GB/1 TB HDD/Wi...   32990
#
#        MRP                                          Processor  Star Rating  \
# ...

# %%
data.drop(['Ram'],axis=1,inplace=True)

# %%
data['Reviews'] = data['Reviews'].str.replace('.', '')

# %% [markdown]
# # Checking for Null Values

# %% [markdown]
# In my data frame no null values

# %%
data.isnull().sum()
# Out:
# Brand_Name    0
# Model_Name    0
# Price         0
# MRP           0
# Processor     0
# Star          0
# Rating        0
# Reviews       0
# Ava_offer     0
# top_rating    0
# Ram_GB        0
# SSD           0
# dtype: int64

# %%
data.dtypes
# Out:
# Brand_Name     object
# Model_Name     object
# Price          object
# MRP            object
# Processor      object
# Star          float64
# Rating         object
# Reviews        object
# Ava_offer      object
# top_rating     object
# Ram_GB          int64
# SSD             int64
# dtype: object

# %%
data['Price'] = data['Price'].astype(int)
data['Star'] = data['Star'].astype(int)
data['Ava_offer'] = pd.to_numeric(data['Ava_offer'],errors = 'coerce')




data['Rating'] = data['Rating'].astype(int)

data['Reviews'] = data['Reviews'].astype(int)

# %%
data['MRP'] = data['MRP'].astype(int)

# %%
data. Brand_Name.unique()
# Out:
# array(['Lenovo', 'HP', 'acer', 'msi', 'DELL', 'ASUS', 'APPLE', 'Mi',
#        'Avita', 'MICROSOFT', 'lenovo', 'Nokia', 'ALIENWARE', 'LG', 'Vaio',
#        'Nexstgo'], dtype=object)

# %%
data['top_rating'].value_counts()
# Out:
# star      371
# below      80
# Name: top_rating, dtype: int64

# %%
data['Ram_GB'].value_counts()
# Out:
# 8    294
# 4     71
# 1     67
# 3     14
# 2      5
# Name: Ram_GB, dtype: int64

# %%
data['Brand_Name'].value_counts()
# Out:
# ASUS         126
# Lenovo        86
# HP            71
# msi           39
# DELL          39
# acer          33
# APPLE         17
# Avita         15
# ALIENWARE      7
# MICROSOFT      6
# Mi             4
# LG             3
# lenovo         2
# Vaio           1
# Nexstgo        1
# Nokia          1
# Name: Brand_Name, dtype: int64

# %% [markdown]
# # Data Visualization (Uni, Bi and Multi-variate)¶
#
# Plot the every variable
#
#     Plots for Numerical and Categorical variables
#     Plots for Numerical to Categorical variable
#     Plots for Categorical to Numerical variables [Box-plot, Bar-plot, count plot, Pie chart, Scatter-plot, violin-plot, Distribution-plot, Heat map, Histogram and kde-plot etc., Use all plots for individual variables]

# %% [markdown]
# # Count plot for every colums

# %%
plt.figure(dpi=100,figsize=(20,7))
sns.countplot(data.Brand_Name )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(40,5))
sns.countplot(data.Price )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(40,5))
sns.countplot(data.MRP )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(15,7))
sns.boxplot(x=data.Brand_Name,y=data.Price);

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(dpi=100,figsize=(20,7))
sns.countplot(data.Star )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(40,5))
sns.countplot(data.Rating )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(20,5))
sns.countplot(data.Reviews )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(20,5))
sns.countplot(data.Ava_offer )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(20,5))
sns.countplot(data.top_rating )
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.pie(data['top_rating'].value_counts(),
             labels=["star","below"],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2098616dac0>,
# ...
#  [Text(-0.9335740330260265, 0.5817555542145857, 'star'),
#   Text(0.9335740057920824, -0.5817555979183398, 'below')])

# %%
plt.figure(dpi=100,figsize=(20,5))
sns.countplot(data.Ram_GB)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(dpi=100,figsize=(20,5))

sns.countplot(data.SSD)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # what are 5-top pricing laptops?

# %%
data.dtypes
# Out:
# Brand_Name    object
# Model_Name    object
# Price          int32
# MRP            int32
# Processor     object
# Star           int32
# Rating         int32
# Reviews        int32
# Ava_offer      int64
# top_rating    object
# Ram_GB         int64
# SSD            int64
# dtype: object

# %%
data.drop(['MRP'], axis=1,inplace=True)

# %% [markdown]
# # checking for top 5 high-cost laptops and low-cost laptops

# %%
top_pricing=data.nlargest(5, ['Price'])

# %%
top_pricing
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 289  ALIENWARE  Core i9 10th Gen - (32 GB/1 TB SSD/Windows 10 ...  344990
# 327  ALIENWARE  Core i7 9th Gen - (16 GB/1 TB HDD/1 TB SSD/Win...  325680
# 199        msi  GE76 Raider Core i7 10th Gen - (32 GB/2 TB SSD...  289990
# 301       ASUS  Core i9 10th Gen - (32 GB/1 TB SSD/Windows 10 ...  269990
# 287  ALIENWARE  Core i7 10th Gen - (16 GB/1 TB SSD/Windows 10 ...  268990
#
#                                              Processor  Star  Rating  Reviews  \
# 289  Intel Core i9 Processor (10th Gen)32 GB DDR4 R...     1      24        5
# 327  Intel Core i7 Processor (9th Gen)16 GB DDR4 RA...     3       2        1
# 199  Intel Core i7 Processor (10th Gen)32 GB DDR4 R...     4       9        0
# 301  Intel Core i9 Processor (10th Gen)32 GB DDR4 R...     4      31        3
# 287  Intel Core i7 Processor (10th Gen)16 GB DDR4 R...     4      14        7
#
#      Ava_offer top_rating  Ram_GB  SSD
# ...

# %%
top_pricing.plot.scatter('Brand_Name','Price')
# Out:
# <AxesSubplot:xlabel='Brand_Name', ylabel='Price'>

# %%
fix, ax=plt.subplots(3,3,figsize=(12,12))
sns.distplot(top_pricing['Price'], ax=ax[0,0])
sns.distplot(top_pricing['SSD'], ax=ax[0,1])
sns.distplot(top_pricing['Star'], ax=ax[0,2])
sns.distplot(top_pricing['Ava_offer'], ax=ax[1,0])
sns.distplot(top_pricing['Reviews'], ax=ax[1,1])
sns.distplot(top_pricing['Reviews'], ax=ax[1,2])
sns.distplot(top_pricing['Rating'], ax=ax[2,0])
sns.distplot(top_pricing['SSD'], ax=ax[2,1])
sns.distplot(top_pricing['Ram_GB'], ax=ax[2,2])


plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# low-pricing laptops

# %%
low_pricing=data.nsmallest(5, ['Price'])

# %%
low_pricing
# Out:
#     Brand_Name                                         Model_Name  Price  \
# 12        ASUS  Celeron Dual Core - (4 GB/1 TB HDD/Windows 10 ...  20990
# 36        ASUS  Celeron Dual Core - (4 GB/1 TB HDD/Windows 10 ...  20990
# 153         HP  Chromebook MT8183 - (4 GB/64 GB EMMC Storage/C...  21990
# 17        acer  One 14 Pentium Gold - (4 GB/1 TB HDD/Windows 1...  22990
# 41        acer  One 14 Pentium Gold - (4 GB/1 TB HDD/Windows 1...  22990
#
#                                              Processor  Star  Rating  Reviews  \
# 12   Intel Celeron Dual Core Processor4 GB DDR4 RAM...     3    5927      774
# 36   Intel Celeron Dual Core Processor4 GB DDR4 RAM...     4     300       38
# 153  MediaTek MT8183 Processor4 GB DDR4 RAM64 bit C...     4     117       16
# 17   Intel Pentium Gold Processor4 GB DDR4 RAM64 bi...     4    8408      998
# 41   Intel Pentium Gold Processor4 GB DDR4 RAM64 bi...     4      12        3
#
#      Ava_offer top_rating  Ram_GB  SSD
# ...

# %%
low_pricing.plot.scatter('Price','Star')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Star'>

# %%
fix, ax=plt.subplots(3,3,figsize=(12,12))
sns.distplot(low_pricing['Price'], ax=ax[0,0])
sns.distplot(low_pricing['SSD'], ax=ax[0,1])
sns.distplot(low_pricing['Star'], ax=ax[0,2])
sns.distplot(low_pricing['Ava_offer'], ax=ax[1,0])
sns.distplot(low_pricing['Reviews'], ax=ax[1,1])
sns.distplot(low_pricing['Reviews'], ax=ax[1,2])
sns.distplot(low_pricing['Rating'], ax=ax[2,0])
sns.distplot(low_pricing['SSD'], ax=ax[2,1])
sns.distplot(low_pricing['Ram_GB'], ax=ax[2,2])
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # checking for top 5 high-rating laptops and low-rating laptops

# %%
hig_rating=data.nlargest(6, ['Star'])

# %%
hig_rating
# Out:
#    Brand_Name                                         Model_Name  Price  \
# 24     Lenovo  Ideapad Slim 3 Celeron Dual Core - (4 GB/256 G...  23990
# 25         HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...  49990
# 31        msi  GF63 Thin Core i5 9th Gen - (8 GB/512 GB SSD/W...  54990
# 37       ASUS  VivoBook 15 Core i5 10th Gen - (8 GB/1 TB HDD/...  42990
# 62       ASUS  ROG Strix G15 Core i5 10th Gen - (8 GB/512 GB ...  69990
# 69       ASUS  VivoBook Ultra 14 Core i5 11th Gen - (8 GB/512...  54990
#
#                                             Processor  Star  Rating  Reviews  \
# 24  Intel Celeron Dual Core Processor4 GB DDR4 RAM...     5    8757     1224
# 25  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64...     5     527       98
# 31  Intel Core i5 Processor (9th Gen)8 GB DDR4 RAM...     5     141       14
# 37  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...     5    1595      162
# 62  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...     5      15        3
# ...

# %%
hig_rating.plot.scatter('Brand_Name','Star')
# Out:
# <AxesSubplot:xlabel='Brand_Name', ylabel='Star'>

# %%
fix, ax=plt.subplots(3,3,figsize=(12,12))
sns.distplot(hig_rating['Price'], ax=ax[0,0])
sns.distplot(hig_rating['SSD'], ax=ax[0,1])
sns.distplot(hig_rating['Star'], ax=ax[0,2])
sns.distplot(hig_rating['Ava_offer'], ax=ax[1,0])
sns.distplot(hig_rating['Reviews'], ax=ax[1,1])
sns.distplot(hig_rating['Reviews'], ax=ax[1,2])
sns.distplot(hig_rating['Rating'], ax=ax[2,0])
sns.distplot(hig_rating['SSD'], ax=ax[2,1])
sns.distplot(hig_rating['Ram_GB'], ax=ax[2,2])
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# lowest rating laptops

# %%
low_rating=data.nsmallest(6, ['Star'])

# %%
low_rating
# Out:
#     Brand_Name                                         Model_Name  Price  \
# 63      Lenovo  Ideapad S 540 Core i5 10th Gen - (8 GB/1 TB HD...  60895
# 102        msi  Modern 14 Core i3 10th Gen - (8 GB/512 GB SSD/...  42990
# 143       ASUS  VivoBook Flip 14 Core i3 10th Gen - (4 GB/512 ...  46990
# 148         HP  15s Core i5 11th Gen - (8 GB/1 TB SSD/Windows ...  64450
# 149     Lenovo  ThinkPad E15 Core i5 10th Gen - (8 GB/1 TB HDD...  59490
# 152       ASUS  VivoBook Ultra 14 Core i5 11th Gen - (8 GB/512...  62990
#
#                                              Processor  Star  Rating  Reviews  \
# 63   Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...     1    2475      289
# 102  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...     1    2097      238
# 143  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...     1      36        6
# 148  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...     1      78       15
# ...

# %%
low_rating.plot.scatter('Brand_Name','Star')
# Out:
# <AxesSubplot:xlabel='Brand_Name', ylabel='Star'>

# %%
fix, ax=plt.subplots(3,3,figsize=(12,12))
sns.distplot(low_rating['Price'], ax=ax[0,0])
sns.distplot(low_rating['SSD'], ax=ax[0,1])
sns.distplot(low_rating['Star'], ax=ax[0,2])
sns.distplot(low_rating['Ava_offer'], ax=ax[1,0])
sns.distplot(low_rating['Reviews'], ax=ax[1,1])
sns.distplot(low_rating['Reviews'], ax=ax[1,2])
sns.distplot(low_rating['Rating'], ax=ax[2,0])
sns.distplot(low_rating['SSD'], ax=ax[2,1])
sns.distplot(low_rating['Ram_GB'], ax=ax[2,2])
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
hig_Reviews=data.nlargest(6, ['Reviews'])

# %%
fix, ax=plt.subplots(3,3,figsize=(12,12))
sns.distplot(hig_Reviews['Price'], ax=ax[0,0])
sns.distplot(hig_Reviews['SSD'], ax=ax[0,1])
sns.distplot(hig_Reviews['Star'], ax=ax[0,2])
sns.distplot(hig_Reviews['Ava_offer'], ax=ax[1,0])
sns.distplot(hig_Reviews['Reviews'], ax=ax[1,1])
sns.distplot(hig_Reviews['Reviews'], ax=ax[1,2])
sns.distplot(hig_Reviews['Rating'], ax=ax[2,0])
sns.distplot(hig_Reviews['SSD'], ax=ax[2,1])
sns.distplot(hig_Reviews['Ram_GB'], ax=ax[2,2])
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
hig_Reviews
# Out:
#     Brand_Name                                         Model_Name  Price  \
# 22        DELL  Inspiron Pentium Quad Core - (4 GB/256 GB SSD/...  31490
# 45         msi  GF65 Thin Core i7 9th Gen - (16 GB/512 GB SSD/...  75990
# 376       DELL  G3 Core i7 10th Gen - (8 GB/512 GB SSD/Windows...  82490
# 379       ASUS  ExpertBook P2 Core i5 10th Gen - (8 GB/1 TB HD...  69290
# 441       acer  Aspire 5 Core i5 11th Gen - (8 GB/512 GB SSD/W...  49990
# 444       ASUS  ExpertBook P2 Core i7 10th Gen - (8 GB/1 TB HD...  93990
#
#                                              Processor  Star  Rating  Reviews  \
# 22   Intel Pentium Quad Core Processor4 GB DDR4 RAM...     4   30205     3269
# 45   Intel Core i7 Processor (9th Gen)16 GB DDR4 RA...     4   30205     3269
# 376  Intel Core i7 Processor (10th Gen)8 GB DDR4 RA...     4   14470     2051
# 379  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...     1   14470     2051
# ...

# %%
hig_Reviews.plot.scatter('Brand_Name','Reviews')
# Out:
# <AxesSubplot:xlabel='Brand_Name', ylabel='Reviews'>

# %%
low_Reviews=data.nsmallest(6, ['Reviews'])

# %%
low_Reviews
# Out:
#     Brand_Name                                         Model_Name  Price  \
# 86        DELL  Inspiron 3505 Ryzen 3 Dual Core 3250U - (8 GB/...  32517
# 128     Lenovo  Ideapad S340 Core i5 10th Gen - (8 GB/512 GB S...  55990
# 134       DELL  Inspiron 3505 Ryzen 7 Quad Core 3700U - (8 GB/...  57890
# 141       DELL  Vostro Core i3 10th Gen - (8 GB/1 TB HDD/Windo...  39990
# 171     Lenovo  ThinkPad E14 Core i3 10th Gen - (4 GB/256 GB S...  37490
# 178        msi  Prestige 14 Core i7 10th Gen - (16 GB/512 GB S...  84990
#
#                                              Processor  Star  Rating  Reviews  \
# 86   AMD Ryzen 3 Dual Core Processor8 GB DDR4 RAM64...     4      19        0
# 128  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...     4       3        0
# 134  AMD Ryzen 7 Quad Core Processor8 GB DDR4 RAM64...     4       6        0
# 141  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...     4       6        0
# ...

# %%
low_Reviews.plot.scatter('Brand_Name','Reviews')
# Out:
# <AxesSubplot:xlabel='Brand_Name', ylabel='Reviews'>

# %%
fix, ax=plt.subplots(3,3,figsize=(12,12))
sns.distplot(low_Reviews['Price'], ax=ax[0,0])
sns.distplot(low_Reviews['SSD'], ax=ax[0,1])
sns.distplot(low_Reviews['Star'], ax=ax[0,2])
sns.distplot(low_Reviews['Ava_offer'], ax=ax[1,0])
sns.distplot(low_Reviews['Reviews'], ax=ax[1,1])
sns.distplot(low_Reviews['Reviews'], ax=ax[1,2])
sns.distplot(low_Reviews['Rating'], ax=ax[2,0])
sns.distplot(low_Reviews['SSD'], ax=ax[2,1])
sns.distplot(low_Reviews['Ram_GB'], ax=ax[2,2])
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
hig_offer=data.nlargest(10, ['Rating'])

# %%
hig_offer
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 22        DELL  Inspiron Pentium Quad Core - (4 GB/256 GB SSD/...   31490
# 45         msi  GF65 Thin Core i7 9th Gen - (16 GB/512 GB SSD/...   75990
# 376       DELL  G3 Core i7 10th Gen - (8 GB/512 GB SSD/Windows...   82490
# 379       ASUS  ExpertBook P2 Core i5 10th Gen - (8 GB/1 TB HD...   69290
# 441       acer  Aspire 5 Core i5 11th Gen - (8 GB/512 GB SSD/W...   49990
# 444       ASUS  ExpertBook P2 Core i7 10th Gen - (8 GB/1 TB HD...   93990
# 368       ASUS  ExpertBook P2 Core i7 10th Gen - (8 GB/1 TB HD...   75990
# 384       ASUS  ZenBook Pro 15 Core i7 8th Gen - (16 GB/1 TB S...  175190
# 1           HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...   49990
# 24      Lenovo  Ideapad Slim 3 Celeron Dual Core - (4 GB/256 G...   23990
#
#                                              Processor  Star  Rating  Reviews  \
# ...

# %%
hig_offer.plot.scatter('Brand_Name','Rating')
# Out:
# <AxesSubplot:xlabel='Brand_Name', ylabel='Rating'>

# %%
fix, ax=plt.subplots(3,3,figsize=(12,12))
sns.distplot(hig_offer['Price'], ax=ax[0,0])
sns.distplot(hig_offer['SSD'], ax=ax[0,1])
sns.distplot(hig_offer['Star'], ax=ax[0,2])
sns.distplot(hig_offer['Ava_offer'], ax=ax[1,0])
sns.distplot(hig_offer['Reviews'], ax=ax[1,1])
sns.distplot(hig_offer['Reviews'], ax=ax[1,2])
sns.distplot(hig_offer['Rating'], ax=ax[2,0])
sns.distplot(hig_offer['SSD'], ax=ax[2,1])
sns.distplot(hig_offer['Ram_GB'], ax=ax[2,2])
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sample=data[['Brand_Name','Price','MRP','Star','Rating','Reviews','Ava_offer','Ram_GB','SSD']]

# %%
sample
# Out:
#     Brand_Name   Price    MRP  Star  Rating  Reviews  Ava_offer  Ram_GB  SSD
# 0       Lenovo   23990  30690     4     495       74         21       4  256
# 1           HP   49990  56144     4    8757     1224         10       8    1
# 2         acer   55990  89990     4     527       98         37       8  512
# 3       Lenovo   59990  82490     4     974      146         27       8    1
# 4       Lenovo   35990  52490     4     178       15         31       8  256
# ..         ...     ...    ...   ...     ...      ...        ...     ...  ...
# 446       acer   57949  44990     5     117       21         14       8  512
# 447     Lenovo   78938  78990     3     917      141          4       8    1
# 448       ASUS  132790  55900     1      38        3         20       8  512
# 449       ASUS   77990  49729     5    1781      238         11       8  512
# 450     Lenovo   32990  44990     4       8        3         15       4    1
#
# [451 rows x 9 columns]

# %%
data['Price'].hist( )

plt.show()

# %%
sample.hist(bins=7,edgecolor='red',width=10)
plt.show()

# %%
data.plot.scatter('Brand_Name','Price')
plt.xticks(rotation=90)
plt.show()

# %%
data.plot.scatter('Brand_Name','Ram_GB')
plt.xticks(rotation=90)
plt.show()

# %%
data.plot.scatter('Brand_Name','Ava_offer')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Box plot

# %%
sns.catplot(x='Price',kind='box',col='top_rating',hue='top_rating',aspect=0.7,data=data,height=3.8)
plt.show()

# %%
plt.boxplot([data["Price"],data["Star"],data["Ava_offer"]])
plt.xticks((1,2,3),["Price","Star","Ava_offer"])
plt.show()

# %%
sns.catplot(x='Ava_offer',kind='box',col='top_rating',hue='top_rating',aspect=0.7,data=data,height=3.8)
plt.show()

# %% [markdown]
# # cat plot

# %%
sns.catplot(x='Brand_Name',y='Price',kind='swarm',col='top_rating',aspect=0.7,data=data)
plt.xticks(rotation=90)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.relplot(x='Brand_Name',y='Price',hue='top_rating',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(y='Brand_Name',x='Star',kind='swarm',col='top_rating',aspect=0.7,data=data)
plt.xticks(rotation=90)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 91.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 76.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.pairplot(data,hue='top_rating')
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
corrMat=data.corr()

# %%
corrMat
# Out:
#               Price       MRP      Star    Rating   Reviews  Ava_offer  \
# Price      1.000000  0.164525 -0.038930 -0.069917 -0.069852   0.026131
# MRP        0.164525  1.000000 -0.016964 -0.024247 -0.018550  -0.053605
# Star      -0.038930 -0.016964  1.000000 -0.072266 -0.083220   0.038633
# Rating    -0.069917 -0.024247 -0.072266  1.000000  0.987280  -0.074835
# Reviews   -0.069852 -0.018550 -0.083220  0.987280  1.000000  -0.080533
# Ava_offer  0.026131 -0.053605  0.038633 -0.074835 -0.080533   1.000000
# Ram_GB    -0.450971 -0.058651 -0.080066 -0.009751  0.009098  -0.019728
# SSD       -0.096152 -0.073867  0.033762  0.004464  0.005765  -0.037448
#
#              Ram_GB       SSD
# Price     -0.450971 -0.096152
# MRP       -0.058651 -0.073867
# Star      -0.080066  0.033762
# Rating    -0.009751  0.004464
# Reviews    0.009098  0.005765
# Ava_offer -0.019728 -0.037448
# Ram_GB     1.000000  0.264557
# SSD        0.264557  1.000000

# %%
sns.heatmap(corrMat, annot=True)
plt.show()

# %%
hig_Ram=data.nlargest(294,['Ram_GB'])

# %%
hig_Ram
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 1           HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...   49990
# 2         acer  Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/512 G...   55990
# 3       Lenovo  Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H - (8 ...   59990
# 4       Lenovo  Ideapad Slim 3i Core i3 10th Gen - (8 GB/256 G...   35990
# 5           HP  14s Core i3 10th Gen - (8 GB/256 GB SSD/Window...   36990
# ..         ...                                                ...     ...
# 445       ASUS  ZenBook Classic Core i5 10th Gen - (8 GB/512 G...  105990
# 446       acer  Aspire 5 Core i5 10th Gen - (8 GB/512 GB SSD/W...   57949
# 447     Lenovo  Ideapad Gaming 3 Core i5 - (8 GB/1 TB HDD/256 ...   78938
# 448       ASUS  ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB ...  132790
# 449       ASUS  ZenBook 13 Core i5 10th Gen - (8 GB/512 GB SSD...   77990
#
#        MRP                                          Processor  Star  Rating  \
# ...

# %%
low_Ram=data.nsmallest(70,['Ram_GB'])

# %%
low_Ram
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 21         msi  GF65 Thin Core i7 9th Gen - (16 GB/512 GB SSD/...   75990
# 45         msi  GF65 Thin Core i7 9th Gen - (16 GB/512 GB SSD/...   75990
# 75         msi  GF75 Thin Core i7 9th Gen - (16 GB/1 TB HDD/25...   79990
# 78          HP  Pavilion Core i5 11th Gen - (16 GB/512 GB SSD/...   66990
# 84         msi  GF65 Thin Core i7 9th Gen - (16 GB/512 GB SSD/...   89990
# ..         ...                                                ...     ...
# 437       acer  Core i7 6th Gen - (16 GB/1 TB HDD/128 GB SSD/W...  179990
# 298       ASUS  ROG Zephyrus S15 Core i7 10th Gen - (32 GB/1 T...  224990
# 300       ASUS  ROG Strix Scar 17 Core i9 10th Gen - (32 GB/2 ...  239990
# 301       ASUS  Core i9 10th Gen - (32 GB/1 TB SSD/Windows 10 ...  269990
# 422        msi  Creator 17 Core i7 10th Gen - (32 GB/1 TB SSD/...  264990
#
#         MRP                                          Processor  Star  Rating  \
# ...

# %%
data['top_pricing'][289]='35'
# Out:
# <ipython-input-172-ac7cb6d5f14a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Ram_GB'][422]='32'

# %%
top_pricing
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 289  ALIENWARE  Core i9 10th Gen - (32 GB/1 TB SSD/Windows 10 ...  344990
# 327  ALIENWARE  Core i7 9th Gen - (16 GB/1 TB HDD/1 TB SSD/Win...  325680
# 199        msi  GE76 Raider Core i7 10th Gen - (32 GB/2 TB SSD...  289990
# 301       ASUS  Core i9 10th Gen - (32 GB/1 TB SSD/Windows 10 ...  269990
# 287  ALIENWARE  Core i7 10th Gen - (16 GB/1 TB SSD/Windows 10 ...  268990
#
#                                              Processor  Star  Rating  Reviews  \
# 289  Intel Core i9 Processor (10th Gen)32 GB DDR4 R...     1      24        5
# 327  Intel Core i7 Processor (9th Gen)16 GB DDR4 RA...     3       2        1
# 199  Intel Core i7 Processor (10th Gen)32 GB DDR4 R...     4       9        0
# 301  Intel Core i9 Processor (10th Gen)32 GB DDR4 R...     4      31        3
# 287  Intel Core i7 Processor (10th Gen)16 GB DDR4 R...     4      14        7
#
#      Ava_offer top_rating  Ram_GB  SSD
# ...

# %%
data['Ram_GB'][327]='16'
# Out:
# <ipython-input-209-69f5c3cd5848>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Ram_GB'][327]='16'

# %%
data['Ram_GB'][287]='289720'
# Out:
# <ipython-input-142-8e473499a6b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['MRP'][287]='289720'

# %%
data
# Out:
#     Brand_Name                                         Model_Name   Price  \
# 0       Lenovo  Ideapad Slim 3 Celeron Dual Core - (4 GB/256 G...   23990
# 1           HP  Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 G...   49990
# 2         acer  Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/512 G...   55990
# 3       Lenovo  Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H - (8 ...   59990
# 4       Lenovo  Ideapad Slim 3i Core i3 10th Gen - (8 GB/256 G...   35990
# ..         ...                                                ...     ...
# 446       acer  Aspire 5 Core i5 10th Gen - (8 GB/512 GB SSD/W...   57949
# 447     Lenovo  Ideapad Gaming 3 Core i5 - (8 GB/1 TB HDD/256 ...   78938
# 448       ASUS  ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB ...  132790
# 449       ASUS  ZenBook 13 Core i5 10th Gen - (8 GB/512 GB SSD...   77990
# 450     Lenovo  Ideapad 3 Core i3 10th Gen - (4 GB/1 TB HDD/Wi...   32990
#
#        MRP                                          Processor  Star  Rating  \
# ...
